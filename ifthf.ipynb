# %%
import pandas as pd

# %%
df = pd.read_excel("/kaggle/input/xss-attacks-dataset/XSS Attack Dataset with 461 entries.xlsx")
df
# Out:
#                           App Names  \
# 0                       XSSDetector
# 1                       Attackers 2
# 2                       Attackers 3
# 3                       Attackers 4
# 4                       Attackers 5
# ..                              ...
# 455          Abloadtool (abload.de)
# 456                   Na Hora Certa
# 457  Große Crafts Show HD Wallpaper
# 458                        Ohmaster
# 459            Kerze Battery Widget
#
#                                            Permissions            API Name  \
# 0    INTERNET,READ_CONTACTS,ACCESS_FINE_LOCATION,AC...         getDeviceId
# 1    INTERNET,READ_CONTACTS,ACCESS_FINE_LOCATION,AC...  getSimSerialNumber
# 2    INTERNET,ACCESS_FINE_LOCATION,ACCESS_COARSE_LO...       Not Sensitive
# 3                   INTERNET,READ_PHONE_STATE,SEND_SMS       Not Sensitive
# 4              INTERNET,READ_CONTACTS,READ_PHONE_STATE       Not Sensitive
# ...

# %%
df.shape
# Out:
# (460, 7)
